# %%
#preprocessing SANBS data

import pandas as pd
import numpy as np
import datetime as dt
from datetime import timedelta

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load merged dataset (donation_donor, deferrals, collec_sites)

df=pd.read_csv("../1_data/private/VitalantData.csv", nrows= 10000)
print(df.columns)
pd.set_option('display.max_columns', 48)
df.head()
# Out:
# Index(['DON_DATE_KEY', 'DONOR_KEY', 'DONOR_NUMBER', 'DONATION_NUMBER',
#        'ACTIVE_DONOR_TYPE', 'SITE_KEY', 'COLLECTION_SITE_KEY',
#        'DONATION_VOLUME_DRAWN', 'DRIVE_ID', 'PHLEB_START_TIME_KEY',
#        'PHLEB_STOP_TIME_KEY', 'PHLEBOTOMY_CODE', 'PHLEBOTOMY_DESC',
#        'PHLEBOTOMY_STATUS', 'DONATION_PROCEDURE_TYPE', 'PHLEBOTOMY_GROUP',
#        'DONATION_TYPE', 'DONATION_BAG_DESCRIPTION', 'DONOR_GENDER',
#        'DONOR_ABORH', 'DONOR_ETHNICITY_DESC', 'RACE_ETHNICITY',
#        'RACE_DESCRIPTION', 'DONOR_COUNTRY_OF_BIRTH', 'DONOR_EDUCATION_DESC',
#        'DONOR_WEIGHT', 'DONOR_HEIGHT', 'DONOR_ZIPCODE',
#        'DONOR_AGE_AT_DONATION', 'COLLECTION_FIXED_LOCATION',
#        'COLLECTION_SITE_VALID_FLAG', 'BECS_ID', 'DRIVE_SETUP_TYPE',
#        'DRIVE_TYPE_FIXED_MOBILE', 'DEFERRAL_EVENT', 'DEFERRAL_INFORMATION',
#        'DEFERRAL_CREATE_DATE', 'DEFERRAL_START_DATE', 'DEFERRAL_STOP_DATE',
#        'DEF_INVALDATION_DATE', 'DEFERRAL', 'DEFERRAL_DESCRIPTION',
#        'DEFERRAL_VALID_CODE', 'DEFERRAL_DURATION', 'DURATION_MODIF_TYPE',
#        'ALLOW_DISTRIBUTION', 'DEFERRAL_GROUP'],
#       dtype='object')
#    DON_DATE_KEY   DONOR_KEY DONOR_NUMBER   DONATION_NUMBER ACTIVE_DONOR_TYPE  \
# 0    20130625.0  15057895.0      82X912T  W28861300166600F            Active
# 1    20140525.0    840652.0      5006735  W04221402205100P        First Time
# 2    20141018.0    792640.0      2109508  W04221404264200Q            Active
# 3    20140726.0   7079135.0      5024441  W04221402021200I        First Time
# 4    20140519.0   6126680.0      4186033  W042214021267009            Active
#
#    SITE_KEY  COLLECTION_SITE_KEY  DONATION_VOLUME_DRAWN  DRIVE_ID  \
# 0    3003.0              62130.0                    NaN       NaN
# 1      51.0                383.0                  500.0     612.0
# 2      51.0                376.0                  452.0     600.0
# 3      51.0                380.0                  500.0     602.0
# 4      51.0                383.0                  440.0     612.0
#
#   PHLEB_START_TIME_KEY PHLEB_STOP_TIME_KEY PHLEBOTOMY_CODE  \
# 0             18:58:01            19:10:01               W
# 1             17:04:01            17:14:01               W
# 2             10:24:01            12:14:01               A
# 3             12:28:01            12:49:01               U
# 4             11:31:01            12:05:01               R
#
#         PHLEBOTOMY_DESC        PHLEBOTOMY_STATUS DONATION_PROCEDURE_TYPE  \
# 0           WHOLE BLOOD    Successful Phlebotomy                   Other
# 1           WHOLE BLOOD    Successful Phlebotomy                      WB
# 2  APHERESIS (PLT/GRAN)    Successful Phlebotomy               Automated
# 3     UNSUCCESSFUL DRAW  Unsuccessful Phlebotomy                      WB
# 4     2RBC - ALLOGENEIC    Successful Phlebotomy               Automated
#
#   PHLEBOTOMY_GROUP DONATION_TYPE             DONATION_BAG_DESCRIPTION  \
# 0      Whole Blood    Allogeneic                Historical Triple Bag
# 1      Whole Blood    Allogeneic              CP2D: Triple RBC Filter
# 2         Platelet    Allogeneic            TRIMA APHERESIS PLATELETS
# 3      Whole Blood    Allogeneic              CP2D: Triple RBC Filter
# 4             2RBC    Allogeneic  HAEMONETICS APHERESIS 2RBC FILTERED
#
#   DONOR_GENDER DONOR_ABORH  DONOR_ETHNICITY_DESC RACE_ETHNICITY  \
# 0            M         O +  NOT HISPANIC - WHITE      White, NH
# 1            M         O +  NOT HISPANIC - WHITE      White, NH
# 2            M         AB+  NOT HISPANIC - WHITE      White, NH
# 3            M         O +  NOT HISPANIC - WHITE      White, NH
# 4            M         O +  NOT HISPANIC - WHITE      White, NH
#
#   RACE_DESCRIPTION            DONOR_COUNTRY_OF_BIRTH  \
# 0              NaN  UNITED STATES (INCLUDING HAWAII)
# 1              NaN  UNITED STATES (INCLUDING HAWAII)
# 2              NaN  UNITED STATES (INCLUDING HAWAII)
# 3              NaN  UNITED STATES (INCLUDING HAWAII)
# 4              NaN  UNITED STATES (INCLUDING HAWAII)
#
#                   DONOR_EDUCATION_DESC  DONOR_WEIGHT  DONOR_HEIGHT  \
# 0                    BACHELOR'S DEGREE         278.0          74.0
# 1     SOME COLLEGE OR TECHNICAL SCHOOL         175.0          69.0
# 2     SOME COLLEGE OR TECHNICAL SCHOOL         205.0          68.0
# 3    HIGH SCHOOL GRAD-DIPLOMA OR EQUIV         190.0          70.0
# 4  9th,10th,11th,12th GRADE-NO DIPLOMA         190.0          69.0
#
#   DONOR_ZIPCODE  DONOR_AGE_AT_DONATION COLLECTION_FIXED_LOCATION  \
# 0           606                   56.0                       Yes
# 1           890                   63.0                        No
# 2           890                   36.0                       Yes
# 3           891                   25.0                       Yes
# 4           864                   18.0                        No
#
#   COLLECTION_SITE_VALID_FLAG BECS_ID DRIVE_SETUP_TYPE DRIVE_TYPE_FIXED_MOBILE  \
# 0                          Y     VTL            Fixed                   Fixed
# 1                          Y     VTL     Mobile Setup                  Mobile
# 2                          Y     VTL            Fixed                   Fixed
# 3                          Y     VTL            Fixed                   Fixed
# 4                          Y     VTL     Mobile Setup                  Mobile
#
#   DEFERRAL_EVENT DEFERRAL_INFORMATION DEFERRAL_CREATE_DATE  \
# 0            NaN                  NaN                  NaN
# 1            NaN                  NaN                  NaN
# 2            NaN                  NaN                  NaN
# 3            NaN                  NaN                  NaN
# 4            NaN                  NaN                  NaN
#
#   DEFERRAL_START_DATE DEFERRAL_STOP_DATE DEF_INVALDATION_DATE  DEFERRAL  \
# 0                 NaN                NaN                  NaN       NaN
# 1                 NaN                NaN                  NaN       NaN
# 2                 NaN                NaN                  NaN       NaN
# 3                 NaN                NaN                  NaN       NaN
# 4                 NaN                NaN                  NaN       NaN
#
#   DEFERRAL_DESCRIPTION DEFERRAL_VALID_CODE  DEFERRAL_DURATION  \
# 0                  NaN                 NaN                NaN
# 1                  NaN                 NaN                NaN
# 2                  NaN                 NaN                NaN
# 3                  NaN                 NaN                NaN
# 4                  NaN                 NaN                NaN
#
#   DURATION_MODIF_TYPE ALLOW_DISTRIBUTION DEFERRAL_GROUP
# 0                 NaN                NaN            NaN
# 1                 NaN                NaN            NaN
# 2                 NaN                NaN            NaN
# 3                 NaN                NaN            NaN
# 4                 NaN                NaN            NaN

# %%
df.loc[df["DEFERRAL_DESCRIPTION"]=='LOW HEMOGLOBIN/HEMATOCRIT'].head()
# Out:
#      DON_DATE_KEY  DONOR_KEY  DONOR_NUMBER   DONATION_NUMBER  \
# 3      20140726.0  7079135.0       5024441  W04221402021200I
# 114    20160422.0  1975408.0       6515106  W06851632103100Z
# 124    20181113.0  6864953.0       2841694  W04221805302800S
# 183    20210701.0  8331139.0       836E6VH  W03622144014100X
# 203    20210614.0  9181112.0  C-2000484824     W087521026647
#
#     ACTIVE_DONOR_TYPE  SITE_KEY  COLLECTION_SITE_KEY  DONATION_VOLUME_DRAWN  \
# 3          First Time      51.0                380.0                  500.0
# 114            Active     171.0                748.0                  500.0
# 124            Active      51.0                383.0                  255.0
# 183            Active     179.0                798.0                  450.0
# 203         Reengaged      57.0               2468.0                    NaN
#
#      DRIVE_ID PHLEB_START_TIME_KEY PHLEB_STOP_TIME_KEY PHLEBOTOMY_CODE  \
# 3       602.0             12:28:01            12:49:01               U
# 114     916.0             15:29:01            15:35:01               U
# 124     211.0             18:00:01            18:32:01               U
# 183     409.0             17:32:01            17:55:01               U
# 203       NaN             19:08:01            19:11:01               R
#
#        PHLEBOTOMY_DESC        PHLEBOTOMY_STATUS DONATION_PROCEDURE_TYPE  \
# 3    UNSUCCESSFUL DRAW  Unsuccessful Phlebotomy                      WB
# 114  UNSUCCESSFUL DRAW  Unsuccessful Phlebotomy                      WB
# 124  UNSUCCESSFUL DRAW  Unsuccessful Phlebotomy               Automated
# 183  UNSUCCESSFUL DRAW  Unsuccessful Phlebotomy                      WB
# 203        TRIMA LS112  Unsuccessful Phlebotomy               Undefined
#
#     PHLEBOTOMY_GROUP DONATION_TYPE    DONATION_BAG_DESCRIPTION DONOR_GENDER  \
# 3        Whole Blood    Allogeneic     CP2D: Triple RBC Filter            M
# 114      Whole Blood    Allogeneic     CP2D: Triple RBC Filter            F
# 124             2RBC    Allogeneic         ALYX APHERESIS 2RBC            F
# 183      Whole Blood    Allogeneic  CPD: Triple RBC Filter Set            M
# 203             2RBC    Allogeneic                     UNKNOWN            M
#
#     DONOR_ABORH                    DONOR_ETHNICITY_DESC RACE_ETHNICITY  \
# 3           O +                    NOT HISPANIC - WHITE      White, NH
# 114         A +                    NOT HISPANIC - WHITE      White, NH
# 124         O +                    NOT HISPANIC - WHITE      White, NH
# 183         O +  NOT HISPANIC - BLACK, AFRICAN AMERICAN      Black, NH
# 203         O +                                     NaN        UNKNOWN
#
#     RACE_DESCRIPTION            DONOR_COUNTRY_OF_BIRTH  \
# 3                NaN  UNITED STATES (INCLUDING HAWAII)
# 114              NaN  UNITED STATES (INCLUDING HAWAII)
# 124              NaN  UNITED STATES (INCLUDING HAWAII)
# 183              NaN  UNITED STATES (INCLUDING HAWAII)
# 203              NaN                           UNKNOWN
#
#                   DONOR_EDUCATION_DESC  DONOR_WEIGHT  DONOR_HEIGHT  \
# 3    HIGH SCHOOL GRAD-DIPLOMA OR EQUIV         190.0          70.0
# 114                 ASSOCIATE'S DEGREE         120.0          59.0
# 124                  BACHELOR'S DEGREE         168.0          67.0
# 183                  BACHELOR'S DEGREE         288.0          75.0
# 203                                NaN         215.0          72.0
#
#     DONOR_ZIPCODE  DONOR_AGE_AT_DONATION COLLECTION_FIXED_LOCATION  \
# 3             891                   25.0                       Yes
# 114           838                   29.0                        No
# 124           890                   53.0                        No
# 183           804                   52.0                       Yes
# 203           160                   38.0                       Yes
#
#     COLLECTION_SITE_VALID_FLAG BECS_ID DRIVE_SETUP_TYPE  \
# 3                            Y     VTL            Fixed
# 114                          Y     VTL           Mobile
# 124                          Y     VTL     Mobile Setup
# 183                          Y     VTL            Fixed
# 203                          Y   ITXMS              NaN
#
#     DRIVE_TYPE_FIXED_MOBILE                       DEFERRAL_EVENT  \
# 3                     Fixed                                  NaN
# 114                  Mobile                                  NaN
# 124                  Mobile  Technical Questionnaire Consequence
# 183                   Fixed                    Medical Screening
# 203                   Fixed                                  NaN
#
#                                   DEFERRAL_INFORMATION DEFERRAL_CREATE_DATE  \
# 3                                                  NaN                  NaN
# 114                                                NaN                  NaN
# 124  Donation W04221805302800S Question 9S Answer 1...           2018-11-15
# 183                          Donation W03622144014100X           2021-07-15
# 203                                                NaN                  NaN
#
#      DEFERRAL_START_DATE   DEFERRAL_STOP_DATE DEF_INVALDATION_DATE  DEFERRAL  \
# 3                    NaN                  NaN                  NaN       NaN
# 114                  NaN                  NaN                  NaN       NaN
# 124  2018-11-13 00:00:00  2019-03-04 00:00:00  9998-12-30 00:00:00    2027.0
# 183  2021-07-01 00:00:00  2021-08-25 00:00:00  9998-12-30 00:00:00    2030.0
# 203                  NaN                  NaN                  NaN       NaN
#
#             DEFERRAL_DESCRIPTION DEFERRAL_VALID_CODE  DEFERRAL_DURATION  \
# 3                            NaN                 NaN                NaN
# 114                          NaN                 NaN                NaN
# 124     2RBC DONATION - 112 DAYS                   Y              111.0
# 183  WB DONATION IN PAST 8 WEEKS                   Y               55.0
# 203                          NaN                 NaN                NaN
#
#                                    DURATION_MODIF_TYPE ALLOW_DISTRIBUTION  \
# 3                                                  NaN                NaN
# 114                                                NaN                NaN
# 124  End Date Can be Lengthened or Shortened (user ...       Always allow
# 183  End Date Can be Lengthened or Shortened (user ...       Always allow
# 203                                                NaN                NaN
#
#     DEFERRAL_GROUP
# 3              NaN
# 114            NaN
# 124     Blood Loss
# 183     Blood Loss
# 203            NaN

# %%
# donor history
#merge with don hist dataset

# %%
#add a column OUTCOME_TYPE that indicates hgb deferal, other deferral or completed donation to indicate deferral type

df.loc[(df['Outcome'] == 'DEFERRAL') & (df["DEFERRAL_DESCRIPTION"]=='LOW HEMOGLOBIN/HEMATOCRIT'), 'OUTCOME_TYPE'] = 'low hgb'
df.loc[(df['Outcome'] == "SUCCESSFUL DONATION"), 'OUTCOME_TYPE'] = 'completed'
df.loc[(df['Outcome'] == "DEFERRAL") & (df["DEFERRAL_DESCRIPTION"]!='LOW HEMOGLOBIN/HEMATOCRIT') , 'OUTCOME_TYPE'] = 'other deferral'
df['OUTCOME_TYPE'].fillna("no draw", inplace=True)

df.drop(df[df['Visit_Date'].isna()].index, inplace=True) #remove any missing visit dates

df["Visit_Date"] = df["Visit_Date"].astype("datetime64") #convert to date time object

df.sort_values(by=['DonorID', 'don_Sequence', 'Visit_Date'], axis = 0, inplace=True)

df['OUTCOME_TYPE'].value_counts()

# %%
print(len(df.loc[df['OUTCOME_TYPE']=='low hgb'])) # number of deferrals
print(len(df))#total observations

# %%
#add censored column (indicates whether row is right censored) 0-censored, 1-notcensored
df['CENSORED']=np.where(df['DonorID'] == df['DonorID'].shift(-1), 1, 0)

#add time_to_return column (time between visits)
#if return exists -> difference between visit dates
#else difference between visit date and end of data collection 2022-12-31

df['time_to_return']= np.where(df['CENSORED']==1, (df['Visit_Date'].shift(-1)-df['Visit_Date'])/np.timedelta64(1, 'D'), (dt.datetime(2022, 12, 31)-df["Visit_Date"])/np.timedelta64(1, 'D'))
#df['time_to_return'].fillna((df['VISIT_DATE'].shift(-1)-df["VISIT_DATE"])/np.timedelta64(1, 'D'), inplace=True)

# %%
#Fixed-Mobile Donations Analysis

#plot number - mobile=0, fixed=1
fixed=df["Fixed"]
#sns.histplot(df, x="Fixed", stat="probability")
#sns.countplot(fixed)
#print(fixed.value_counts())

# group and remove some categories that are not fixed or mobile
# administrative site and apheresis clinic fall under fixed
# exclude others

df.drop(df[(df['Fixed']== 'Lapsed Clinic') | (df['Fixed']=='Processing Lab')| (df['Fixed']=='Unallocated') 
           | (df["Fixed"]== 'Laboratorium') |(df["Fixed"]=='Doctor')].index, inplace=True)

df['Fixed_mobile'] = np.where(df['Fixed'] == 'Mobile Clinic', 0, 1) #mobile is 0, fixed is 1
sns.histplot(df, x="Fixed_mobile", stat="probability")

#create a column to indicate 
    #1. mobile then mobile - mm
    #2. mobile then fixed -mf
    #3. fixed then fixed - ff
    #4. fixed then mobile - fm

df["FIXED_NEXT"] = np.where(df['DonorID'] == df['DonorID'].shift(-1), df['Fixed_mobile'].shift(-1), 10)
df.loc[((df['FIXED_NEXT']== 1) & (df['Fixed_mobile']== 1)), 'fixed_mobile_pattern'] = 'FF'

df.loc[((df['FIXED_NEXT']==0) & (df['Fixed_mobile']== 0)), 'fixed_mobile_pattern']= 'MM'

df.loc[((df['FIXED_NEXT']==0) & (df['Fixed_mobile']== 1)), 'fixed_mobile_pattern'] = 'FM'

df.loc[((df['FIXED_NEXT']==1) & (df['Fixed_mobile']== 0)), 'fixed_mobile_pattern']= 'MF'
df['fixed_mobile_pattern'].fillna('last', inplace=True)


#Plot fixed pattern
#create value count
plt.figure()
sns.histplot(df, x="fixed_mobile_pattern", stat="probability")
#sns.countplot(fixed_mobile)



# percent population fixed vs mobile by year
# - do people go back to the same mobile site?
# - how many people never completed donation?

plt.figure()
sns.histplot(data=df, x="Visit_yr", hue="Fixed_mobile", binwidth=1)

# the % of each resulting in hemoglobin deferral or other deferral

print(len(df.loc[((df['OUTCOME_TYPE']=="low hgb") & (df['Fixed_mobile']== 1))])/len(df.loc[(df['Fixed_mobile']==1)]))
print(len(df.loc[((df['OUTCOME_TYPE']=="low hgb") & (df['Fixed_mobile']== 0))])/len(df.loc[(df['Fixed_mobile']==0)]))

print(len(df.loc[(df['Fixed_mobile']==1)]))
print(len(df.loc[(df['Fixed_mobile']==0)]))

# %%
# drop permamnent deferrals

# %%
# drop non-whole blood and rbc don_procs

# %%
#compute time_to_return with shifts for completed donation: subtract 56 days 

df['time_to_return'] = np.where(df['OUTCOME_TYPE'] == 'completed', (df['time_to_return'] - 56), df['time_to_return'])

#compute time_to_return with shifts for other donations
#first covert eligibilty year and month to a datetime object

df["Def_end"] = df["Def_end"].astype("datetime64")
#df['Def_end'].isna().sum()

#hgb deferrals
df['time_to_return'] = np.where(df['OUTCOME_TYPE'] == 'low hgb', (df['time_to_return'] - ((df['Def_end'] - df['Visit_Date'])/np.timedelta64(1, 'D'))), df['time_to_return'])

#other deferrals
df['time_to_return'] = np.where(df['OUTCOME_TYPE'] == 'other deferral', (df['time_to_return'] - ((df['Def_end'] - df['Visit_Date'])/np.timedelta64(1, 'D'))), df['time_to_return'])
df['time_to_return'].isna().sum()

#df.loc['OUTCOME_TYPE','time_to_return', 'Def_end'].head(25)

# %%
#write preprocessed data to csv
df.to_csv(("../1_data/private/preprocessed_data.csv"), index=False)
